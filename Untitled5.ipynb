# %% [markdown]
# <a href="https://colab.research.google.com/github/ledangnam20146507/AI-Course-Homework-1/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas.core.arrays.datetimes import conversion
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file ='mtcars.csv'
data = pd.read_csv(file)
data.head(86)

x1 = np.array(data['mpg'])
y = np.array(data['wt'])

plt.scatter(x1,y)
plt.xlabel('mpg',fontsize = 10)
plt.xlabel('wt',fontsize = 10)
plt.show()

# %%
from sklearn import linear_model
from pandas.core.arrays.datetimes import conversion
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file ='mtcars.csv'
data = pd.read_csv(file)
data.head(86)
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['wt']),y=data['mpg'])
print(model.intercept_)
print(model.coef_)
model.score(pd.DataFrame(data['wt']),data['mpg'])# phan tram do tin cay
y_pred = model.predict(X=pd.DataFrame(data['wt']))
versidual = data['mpg']-y_pred
versidual.describe()

data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='red')
plt.plot(data['wt'],y_pred,color='blue')
model=linear_model.LinearRegression()

model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2]).T
model.fit(X, y = data['mpg'])
print('Intercept cua mo hinh bac 2')
print(model.intercept_)
print('coeffient cua mo hinh bac 2')
print(model.coef_)
print('do chinh xac cua man hinh')
print(model.score(X,data['mpg']))
# Out:
# 37.28512616734204
# [-5.34447157]
# Intercept cua mo hinh bac 2
# 49.93081094945181
# coeffient cua mo hinh bac 2
# [-13.38033708   1.17108689]
# do chinh xac cua man hinh
# 0.8190613581384094

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.utils.Path import random
data= pd.read_csv('Advertising.csv')
data.head()
sns.pairplot(data)
corr=data.corr()
sns.heatmap(corr,annot=True)
X=data.drop('TV',axis=True)
y=data['TV']
X.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-69-458691975c55> in <module>
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 from IPython.utils.Path import random
#       6 data= pd.read_csv('Advertising.csv')
#       7 data.head()
#
# ModuleNotFoundError: No module named 'IPython.utils.Path'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
range=np.arange(1.5,5.5,0.1)

predictor=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='red',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# do chinh xac cua man hinh
# 0.8190613581384094
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data= pd.read_csv('50_Startups.csv')
data.head()
sns.pairplot(data)
corr=data.corr()
sns.heatmap(corr,annot=True)
X=data.drop('Profit',axis=True)
y=data['Profit']
X.head()
from sklearn import StandardScaler
sc= StandardScaler()
X=sc.fit_transform(X)
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-52-8cbcc915bff2> in <module>
#      11 y=data['Profit']
#      12 X.head()
# ---> 13 from sklearn import StandardScaler
#      14 sc= StandardScaler()
#      15 X=sc.fit_transform(X)
#
# ImportError: cannot import name 'StandardScaler' from 'sklearn' (/usr/local/lib/python3.9/dist-packages/sklearn/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from sklearn.linear_model import LinearRegression

regressor=LinearRegression()
regressor.fit(X_train,y_train)
y_pred=regressor.product(X_test).round(1)
caculation=pd.DataFrame(np.c_[y_test,y_pred])
column=['Orginal Profit','Predictor Profit']
X=data.drop('Profit',axis=True)
y=data['Profit']
X.head()
from sklearn import StandardScaler
sc= StandardScaler()
X=sc.fit_transform(X)
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-6e5f58ad39d4> in <module>
#       2
#       3 regressor=LinearRegression()
# ----> 4 regressor.fit(X_train,y_train)
#       5 y_pred=regressor.product(X_test).round(1)
#       6 caculation=pd.DataFrame(np.c_[y_test,y_pred])
#
# NameError: name 'X_train' is not defined

# %%
model_10=linear_model.LinearRegression()

X= pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10]).T
model_10.fit(X,y=data['mpg'])

print("Intercpet of model two degrees:")
print(model_10.intercept_)
print('Cofienct of model two degrees:')
print(model_10.coef_)
print('The accuracy of the model')
print(model_10.score(X,data['mpg']))
#--------------------------
range=np.arange(1.5,5.5,0.1)
predictor_10=pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred= model_10.predict(X=predictor_10)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# Intercpet of model two degrees:
# -14921.11995188375
# Cofienct of model two degrees:
# [ 6.45813558e+04 -1.20086131e+05  1.26931928e+05 -8.46598454e+04
#   3.73155199e+04 -1.10334755e+04  2.16590404e+03 -2.70730544e+02
#   1.94974162e+01 -6.15515436e-01]
# The accuracy of the model
# 0.8702106571479111
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
range=np.arange(1.5,5.5,0.1)

predictor=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='red',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
