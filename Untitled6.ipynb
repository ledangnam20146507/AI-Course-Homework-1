# %% [markdown]
# <a href="https://colab.research.google.com/github/ledangnam20146507/AI-Course-Homework-1/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import cifar100
(x_train,y_train),(x_test,y_test)=cifar100.load_data()
x_train=x_train.reshape(50000,32*32*3)
x_train=x_train.astype('float32')/255

# %%
from keras.utils import to_categorical
y_train=to_categorical(y_train,100)
y_test=to_categorical(y_test,100)
print(y_train.shape)
print(y_test.shape)

# %%
from keras.layers import Dense
from keras.models import Sequential
model=Sequential()
model.add(Dense(2000, input_shape = (32*32*3,), activation = 'relu'))
model.add(Dense(1000, activation = 'relu'))
model.add(Dense(100, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 2000)              6146000
#
#  dense_3 (Dense)             (None, 1000)              2001000
#
#  dense_4 (Dense)             (None, 100)               100100
#
# ...
# Total params: 8,247,100
# Trainable params: 8,247,100
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train, y_train, epochs=10, batch_size=128)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 76s 191ms/step - loss: 4.3102 - accuracy: 0.0685
# Epoch 2/10
# 391/391 [==============================] - 71s 182ms/step - loss: 3.7257 - accuracy: 0.1308
# Epoch 3/10
# 391/391 [==============================] - 75s 193ms/step - loss: 3.5358 - accuracy: 0.1642
# Epoch 4/10
# 391/391 [==============================] - 73s 185ms/step - loss: 3.4089 - accuracy: 0.1890
# Epoch 5/10
# 391/391 [==============================] - 78s 198ms/step - loss: 3.3035 - accuracy: 0.2074
# Epoch 6/10
# 391/391 [==============================] - 69s 177ms/step - loss: 3.2141 - accuracy: 0.2230
# Epoch 7/10
# 391/391 [==============================] - 71s 182ms/step - loss: 3.1292 - accuracy: 0.2391
# Epoch 8/10
# 391/391 [==============================] - 72s 185ms/step - loss: 3.0594 - accuracy: 0.2532
# Epoch 9/10
# 391/391 [==============================] - 94s 241ms/step - loss: 2.9858 - accuracy: 0.2677
# Epoch 10/10
# ...

# %%
model100=load('')

# %%
import matplotlib.pyplot as plt
import numpy as np

from keras.models import load_model
from keras.utils import load_img,img_to_array
img=load_img('/content/drive/MyDrive/ga.jpg')
plt.imshow(img)
plt.show()

# %%
img=load_img('/content/drive/MyDrive/ga.jpg',target_size=(32,32))
plt.imshow(img)

# %%
img = img_to_array(img)
img=img.reshape(1,32*32*3)
img=img.astype('float32')
img=img/255
np.argmax(model.predict(img),axis=-1)
# Out:
# 1/1 [==============================] - 0s 102ms/step
# array([74])

# %%
from matplotlib.image import imread
folder='/content/drive/MyDrive/AI'
for i in range(5)
 plt.subplot(1,5,i+1)
 filename=folder+'A'+str(i)+'.jpg'
 img=imread(filename)
 plt.imshow(img)
 plt.show()
# Out:
#   File "<ipython-input-60-154462336f1e>", line 3
#     for i in range(5)
#                      ^
# SyntaxError: invalid syntax

# %%
#boston_houseing
from keras.datasets import boston_housing 
from sklearn.preprocessing import StandardScaler
from keras.layers import Dense
from keras.models import Sequential

(x_train,y_train),(x_test,y_test)=boston_housing.load_data()
sc= StandardScaler()
print(x_train.shape)
sc.fit(x_train)

x_train =sc.transform(x_train)
x_test=sc.transform(x_test)
# Out:
# (404, 13)

# %%
model=Sequential()
model.add(Dense(2000, input_shape = (32*32*3,), activation = 'relu'))
model.add(Dense(1000, activation = 'relu'))
model.add(Dense(100, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_17 (Dense)            (None, 2000)              6146000
#
#  dense_18 (Dense)            (None, 1000)              2001000
#
#  dense_19 (Dense)            (None, 100)               100100
#
# ...
# Total params: 8,247,100
# Trainable params: 8,247,100
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='mean_absoluate_error',metrics=['accuracy'])

# %%
import pandas as pd
df=dataframe()

# %%
model.fit(x_train, y_train, epochs=100, batch_size=128)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-8b231a7286ee> in <cell line: 1>()
# ----> 1 model.fit(x_train, y_train, epochs=100, batch_size=128)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ...
